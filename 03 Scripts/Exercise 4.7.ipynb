# %% [markdown]
# Exercise 4.7 Reading tasks

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Assign path
path = r'C:\Users\djval\Google Drive\Career\Career Foundry\Data Immerson\Achievement 4\10-2021 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\djval\\Google Drive\\Career\\Career Foundry\\Data Immerson\\Achievement 4\\10-2021 Instacart Basket Analysis'

# %%
# Import orders_products_merged
df_ords_prods_merged = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1        26       33120                  5          0   153404    prior
# 2       120       33120                 13          0    23750    prior
# 3       327       33120                  5          1    58707    prior
# 4       390       33120                 28          1   166654    prior
#
#    order_number  orders_day_of_week  order_hour_of_day  \
# 0             3                   5                  9
# 1             2                   0                 16
# 2            11                   6                  8
# 3            21                   6                  9
# 4            48                   0                 12
#
#    days_since_prior_order        product_name  aisle_id  department_id  \
# 0                     8.0  Organic Egg Whites        86             16
# ...

# %%
# Create subset of 1000000 rows
df_ords_prods_merged = df_ords_prods_merged[:1000000]

# %%
df_ords_prods_merged.shape
# Out:
# (1000000, 15)

# %%
# Define a function

def price_label (row):
    if row['prices']<=5:
        return 'Low-range product'
    elif (row['prices']>5) and (row['prices']<=15):
        return 'Mid-range product'
    elif row['price']>15:
        return 'High range'
    else: return 'Not enough data'

# %%
# Apply the function

df_ords_prods_merged['price lable'] = df_ords_prods_merged.apply(price_label,axis = 1)

# %%
# Check the values in the new column

df_ords_prods_merged['price lable'].value_counts(dropna = False)
# Out:
# Mid-range product    983807
# Low-range product     16193
# Name: price lable, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1        26       33120                  5          0   153404    prior
# 2       120       33120                 13          0    23750    prior
# 3       327       33120                  5          1    58707    prior
# 4       390       33120                 28          1   166654    prior
#
#    order_number  orders_day_of_week  order_hour_of_day  \
# 0             3                   5                  9
# 1             2                   0                 16
# 2            11                   6                  8
# 3            21                   6                  9
# 4            48                   0                 12
#
#    days_since_prior_order        product_name  aisle_id  department_id  \
# 0                     8.0  Organic Egg Whites        86             16
# ...

# %%
# Check what the most expensive product is within the subset
df_ords_prods_merged['prices'].max()
# Out:
# 13.7

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <=15) & (df_ords_prods_merged['prices'] >5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    983807
# Low-range product     16193
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1        26       33120                  5          0   153404    prior
# 2       120       33120                 13          0    23750    prior
# 3       327       33120                  5          1    58707    prior
# 4       390       33120                 28          1   166654    prior
#
#    order_number  orders_day_of_week  order_hour_of_day  \
# 0             3                   5                  9
# 1             2                   0                 16
# 2            11                   6                  8
# 3            21                   6                  9
# 4            48                   0                 12
#
#    days_since_prior_order        product_name  aisle_id  department_id  \
# 0                     8.0  Organic Egg Whites        86             16
# ...

# %%
# Import orders_products_merged to run loc. on entire dataframe
df_ords_prods_merged = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged.pkl'))

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <=15) & (df_ords_prods_merged['prices'] >5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %%
# If-statement with For-loop example

for x in range (30,45):
    print("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
# Frequency of the orders_day_of_week

df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_week, dtype: int64

# %%
# Determine busiest and slowest days

result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Redularly busy")

# %%
result
# Out:
# ['Redularly busy',
#  'Busiest day',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest day',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest day',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Least busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest day',
#  'Redularly busy',
#  'Least busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest day',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest day',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
# ...

# %%
df_ords_prods_merged['busiest_day']=result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Redularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# Exercise 4.7 Task

# %%
# Update buiest and slowest days inforamtion

result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest days")
    elif value == 1:
        result.append("Busiest days")    
    elif value == 3:
        result.append("Least busy")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Redularly busy")

# %%
result
# Out:
# ['Redularly busy',
#  'Busiest days',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest days',
#  'Redularly busy',
#  'Redularly busy',
#  'Least busy',
#  'Least busy',
#  'Busiest days',
#  'Redularly busy',
#  'Busiest days',
#  'Redularly busy',
#  'Busiest days',
#  'Redularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Busiest days',
#  'Least busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest days',
#  'Least busy',
#  'Busiest days',
#  'Redularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Least busy',
#  'Redularly busy',
#  'Least busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Least busy',
#  'Busiest days',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Redularly busy',
#  'Least busy',
#  'Busiest days',
# ...

# %%
df_ords_prods_merged['busiest_days']=result

# %%
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Redularly busy    12927461
# Busiest days      11875462
# Least busy         7631289
# Name: busiest_days, dtype: int64

# %% [markdown]
# Based on the amounts in the frequency of the orders_day_of_week, the number of busiest days is equal to the total of 0 and 1 and the slowest days equal to the total of 3 and 4. I am not sure how to create a loop with multiple value checks in one line? I tried the below and it did not work.
#
# for value in df_ords_prods_merged["orders_day_of_week"]:
#     if value == 0 and values == 1:
#         result.append("Busiest days")
#     elif value == 3 and value == 4:
#         result.append("Least busy")
#     else:
#         result.append("Redularly busy"

# %%
# Frequency of the busiest hours of the day

df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
# Determine busiest and slowest hours of the day

result = []

for value in df_ords_prods_merged["order_hour_of_day"]:
    if value <= 17 and value > 8:
        result.append("Most orders")
    elif value <=5:
        result.append("Fewest orders")    
    else:
        result.append("Average orders")

# %%
result
# Out:
# ['Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
df_ords_prods_merged['orders_per_time_period']=result

# %%
df_ords_prods_merged['orders_per_time_period'].value_counts(dropna = False)
# Out:
# Most orders       23226714
# Average orders     8610682
# Fewest orders       596816
# Name: orders_per_time_period, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         2       33120                  1          1   202279    prior
# 1        26       33120                  5          0   153404    prior
# 2       120       33120                 13          0    23750    prior
# 3       327       33120                  5          1    58707    prior
# 4       390       33120                 28          1   166654    prior
#
#    order_number  orders_day_of_week  order_hour_of_day  \
# 0             3                   5                  9
# 1             2                   0                 16
# 2            11                   6                  8
# 3            21                   6                  9
# 4            48                   0                 12
#
#    days_since_prior_order        product_name  aisle_id  department_id  \
# 0                     8.0  Organic Egg Whites        86             16
# ...

# %%
# export df_ords_prods_merged with new columns

df_ords_prods_merged.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged_2.pkl'))
